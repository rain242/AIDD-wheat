# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据准备
molecules = ['3Å', '4Å', '5Å']
amp_values = [-67.11, -63.11, -86.57]
phe_values = [-44.76, -45.66, -43.18]

# 马卡龙配色方案
colors = {'AMP': '#A8E6CF', 'PHE': '#FFAAA5'}
edge_colors = {'AMP': '#45B7AF', 'PHE': '#FF6F69'}

# 创建画布
plt.figure(figsize=(10, 6), dpi=100)
bar_width = 0.35
x_indexes = np.arange(len(molecules))

# 绘制柱状图
amp_bars = plt.bar(x_indexes - bar_width/2, amp_values, bar_width,
                  color=colors['AMP'], edgecolor=edge_colors['AMP'],
                  linewidth=1.5, label='AMP-07')

phe_bars = plt.bar(x_indexes + bar_width/2, phe_values, bar_width,
                  color=colors['PHE'], edgecolor=edge_colors['PHE'],
                  linewidth=1.5, label='Phenamacril')

# 添加数值标签
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.2f}',
                ha='center', va='bottom', fontsize=9)

add_labels(amp_bars)
add_labels(phe_bars)

# 图表装饰
plt.xticks(x_indexes, molecules)
plt.ylabel('Binding Free Energy (kcal/mol)', fontsize=12)
plt.ylim(-100, 0)
plt.title('MM/GBSA Binding Free Energy Comparison', pad=20, fontsize=14)
plt.gca().invert_yaxis()  # 反转Y轴

# 添加图例和网格
plt.legend(frameon=False, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# 调整布局
plt.tight_layout()
plt.show()

# %%
import matplotlib
import numpy

# %%
matplotlib.__version__
# Out:
# '3.9.2'

# %%
numpy.__version__
# Out:
# '1.26.4'
